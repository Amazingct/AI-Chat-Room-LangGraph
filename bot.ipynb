# %% [markdown]
# Done! Congratulations on your new bot. You will find it at t.me/CurateLearnBot. You can now add a description, about section and profile picture for your bot, see /help for a list of commands. By the way, when you've finished creating your cool bot, ping our Bot Support if you want a better username for it. Just make sure the bot is fully operational before you do this.
#
# Use this token to access the HTTP API:
# 7584248314:AAE4nWM5UbajqMybaN0E7pg-U10vW3jRWMI
# Keep your token secure and store it safely, it can be used by anyone to control your bot.
#
# For a description of the Bot API, see this page: https://core.telegram.org/bots/api

# %%
API_KEY="7584248314:AAE4nWM5UbajqMybaN0E7pg-U10vW3jRWMI"
import telebot

# %%
bot = telebot.TeleBot(API_KEY)

# %%
@bot.message_handler()
def greet(message):
    print(message)
    #bot.reply_to(message, "Hey, I am working")
    bot.send_message(message.chat.id, "Whatsup")
bot.polling()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Desktop/Projects/Agents/AI-Chat-Room-LangGraph/.venv/lib/python3.12/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/Desktop/Projects/Agents/AI-Chat-Room-LangGraph/.venv/lib/python3.12/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...

# %%
bot.
